# %%
import tweepy
from tweepy import OAuthHandler
import json

# %%
consumer_key = '80IMctkLHQgzPgWxXjUwG6DYA'
consumer_secret = 'HHQt4vp1Qvbp0DYu8XFCOj2VrqDkafUHenf4MYJu1PQ77fk3h9'

# authorization
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
access_token = '846543252094275585-Cvtsq07cjXHyigMzA0FeqwONc8eXrdX'
access_token_secret = 'ononypFLGiSuMeTfhOs7HhLbNAEyQMJLHlwJ67hDTnrbc'

# authorization
auth.set_access_token(access_token, access_token_secret)

# %%
# generationg twitter API
api = tweepy.API(auth)

keyword = 'LinkNYC' # keyword to search
search = [] 

cnt = 1
while(cnt<=1):
    tweets = api.search(keyword) #api.search(keyword)
    for tweet in tweets:
        search.append(tweet)
    cnt += 1

# %%
print(len(search))
print(search[0])
# Out:
# 15
# ...

# %%
data = {}
i = 0
for tweet in search:
    data['text'] = tweet.text
    data['date'] = tweet.created_at
    data['id'] = tweet.id
    print i, ":", data
    print
    i += 1
# Out:
# 0 : {'date': datetime.datetime(2017, 4, 6, 2, 43, 8), 'text': u'Speaking of #Linknyc the homeless harass us for change and spend the day charging an $800 iPhone for free.  What am I missing here?', 'id': 849814702553214977L}
#
# 1 : {'date': datetime.datetime(2017, 4, 6, 2, 41, 49), 'text': u"#Linknyc NYC's brilliant idea for an open invitation for public masterbation", 'id': 849814370444087298L}
#
# 2 : {'date': datetime.datetime(2017, 4, 6, 1, 21, 24), 'text': u"RT @aissataTINL: Wohoo!I'm doing a #happydance \U0001f483\U0001f3fe b/c #NYCJuniorAmbassador #LinkNYC ad is out! Check it out and celebrate #NYCYouth relatio\u2026", 'id': 849794135452155904L}
#
# 3 : {'date': datetime.datetime(2017, 4, 6, 0, 36, 12), 'text': u'RT @Azi: "We will continue 2 implement strict privacy policies 4 public wi-fi directly provided by the City, such as LinkNYC" https://t.co/\u2026', 'id': 849782758603980802L}
#
# ...

# %% [markdown]
# # Another way

# %%
def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
for idx, status in enumerate(tweepy.Cursor(api.home_timeline).items(30)):
    # Process a single status
    print idx, status.text, status.created_at
# Out:
# 0 Check out the new Links new along 5th Avenue between Degraw St &amp; 12th St #FindALink #ParkSlope #Brooklyn https://t.co/L6LoLfpqB1 2017-04-05 21:15:53
# 1 We value user privacy &amp; will continue to put our users first https://t.co/IIxHiDOrkE @MiguelGamino @AnneMRoest @Azi https://t.co/lNmLkAfUGM 2017-04-05 20:28:02
# 2 RT @JenMarieHensley: Proud that @LinkNYC will always put our users first! https://t.co/Ijjwj8lvPv 2017-04-05 15:58:53
# 3 Joint statement by @AnneMRoest &amp; @MiguelGamino on the Repeal of Federal Internet Privacy Protections https://t.co/9D3UY2thvK @NYCDoITT 2017-04-05 15:54:46
# 4 RT @Azi: "We will continue 2 implement strict privacy policies 4 public wi-fi directly provided by the City, such as LinkNYC" https://t.co/… 2017-04-05 15:24:26
# 5 RT @globalnyc: Even in the rain, Team IA is proud that 7th grade #NYCJuniorAmbssadors are actively engaged w/ the @UN #NYCxUN https://t.co/… 2017-04-05 15:05:55
# ...

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(status._json)
# Out:
# {"contributors": null, "truncated": false, "text": "Check out the new Links new along 5th Avenue between Degraw St &amp; 12th St #FindALink #ParkSlope #Brooklyn https://t.co/L6LoLfpqB1", "is_quote_status": true, "in_reply_to_status_id": null, "id": 849732347373203460, "favorite_count": 1, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "quoted_status_id": 849729639773818880, "retweeted": false, "coordinates": null, "quoted_status": {"contributors": null, "truncated": false, "text": "New Free Wi-Fi/Phone Charging Kiosks Installed Along 5th Avenue @LinkNYC\nhttps://t.co/4t7KzOm6bL https://t.co/loWAv3INuN", "is_quote_status": false, "in_reply_to_status_id": null, "id": 849729639773818880, "favorite_count": 1, "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [{"id": 2815061384, "indices": [64, 72], "id_str": "2815061384", "screen_name":
# ...

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(tweet._json)
# Out:
# {"contributors": null, "truncated": false, "text": "\uc0ac\uc2e4 \ud2b8\ub7fc\ud504\ub3c4 \ub611\uac19\uc740 \ubc1c\uc5b8\uc744 \ud588\uc5c8\ub2e4. \"\ub2c8\uac00 \ud798\ub4e0\uc77c \ud558\uace0 \uc57c\uadfc\ud558\uba74 \ub429\ub2c8\ub2e4\" \uadf8\ub9ac\uace0 \uc5b8\ub860\uc5d0\uac8c \uc870\ub871\ubc1b\uc558\uc9c0.(\ud3ed\uc18c) https://t.co/vmYtKYkKfH", "is_quote_status": true, "in_reply_to_status_id": null, "id": 849804659870932992, "favorite_count": 0, "entities": {"symbols": [], "user_mentions": [], "hashtags": [], "urls": [{"url": "https://t.co/vmYtKYkKfH", "indices": [62, 85], "expanded_url": "https://twitter.com/wjsejguq_/status/849798046162444288", "display_url": "twitter.com/wjsejguq_/stat\u2026"}]}, "quoted_status_id": 849798046162444288, "retweeted": false, "coordinates": null, "quoted_status": {"contributors": null, "truncated": false, "text": "https://t.co/5k4gtcExrY\n\ucc9c\uc870\uad6d \uc5ec\uad50\uc218 \uc77c\uce68", "is_quote_status": false, "in_reply_to_status_id": 
# ...

# %%
print(len(search))
print(search[0])
# Out:
# 15
# ...

# %%
type(search[1])
# Out:
# tweepy.models.Status

# %%
for idx, tweet in enumerate(search):
    print idx,":", tweet.text
# Out:
# 0 : RT @regulardoge: 이반카 트럼프가 중국에서 "여신"으로 추앙받으며 "커리어와 가족을 다 가질 수 있다고 말해주는 페미니즘"의 상징으로 여겨진다고 한다 특히 젊은 비즈니스/IT 계열 종사자(여성)들에게... 뭐가 어디부터 잘못됐는지도 모르…
# 1 : RT @veryjust: 홍준표 지지율이 심상정의 2배가 넘는다니 ㅋㅋㅋㅋㅋ
# 똑똑함 폭발하는 여자가 술주정뱅이 같은 아재를 못이김 ㅋㅋㅋ 트럼프-힐러리 보는 것 같고 그르네
# 2 : RT @Qkind: 트럼프, 맹수 사냥규제 완화 `어린 곰, 늑대도 사냥 가능...` https://t.co/jlYpq9orMo
# -이로써 항공기 사냥이나 새끼 맹수 사냥 등 비윤리적 사냥이 가능해질 전망이다
# 3 : RT @veryjust: 홍준표 지지율이 심상정의 2배가 넘는다니 ㅋㅋㅋㅋㅋ
# 똑똑함 폭발하는 여자가 술주정뱅이 같은 아재를 못이김 ㅋㅋㅋ 트럼프-힐러리 보는 것 같고 그르네
# 4 : RT @veryjust: 홍준표 지지율이 심상정의 2배가 넘는다니 ㅋㅋㅋㅋㅋ
# 똑똑함 폭발하는 여자가 술주정뱅이 같은 아재를 못이김 ㅋㅋㅋ 트럼프-힐러리 보는 것 같고 그르네
# 5 : RT @veryjust: 홍준표 지지율이 심상정의 2배가 넘는다니 ㅋㅋㅋㅋㅋ
# 똑똑함 폭발하는 여자가 술주정뱅이 같은 아재를 못이김 ㅋㅋㅋ 트럼프-힐러리 보는 것 같고 그르네
# 6 : RT @SBS8news: 미국 하버드대학교 대학원생들이 민주주의에 위배된다고 판단한 '트럼프 정책'에 맞서기 위해 '덤블도어 군대'를 결성했습니다. https://t.co/KOfj2vdyet https://t.co/BoSksF47gj
# 7 : RT @kkangchong0321: 트럼프버스 (Trump verse)
#
# 물론 그럴 일은 없겠지만..연성 잘 해주세요... https://t.co/8mXsRieuZ4
# ...

# %%
data = {}
i = 0
for tweet in search:
    data['text'] = tweet.text
    print i, ":", data
    print
    i += 1
# Out:
# 0 : {'text': u"RT @aissataTINL: Wohoo!I'm doing a #happydance \U0001f483\U0001f3fe b/c #NYCJuniorAmbassador #LinkNYC ad is out! Check it out and celebrate #NYCYouth relatio\u2026"}
#
# 1 : {'text': u'RT @Azi: "We will continue 2 implement strict privacy policies 4 public wi-fi directly provided by the City, such as LinkNYC" https://t.co/\u2026'}
#
# 2 : {'text': u'RT @Azi: "We will continue 2 implement strict privacy policies 4 public wi-fi directly provided by the City, such as LinkNYC" https://t.co/\u2026'}
#
# 3 : {'text': u'RT @LinkNYC: We value user privacy &amp; will continue to put our users first https://t.co/IIxHiDOrkE @MiguelGamino @AnneMRoest @Azi https://t.\u2026'}
#
# 4 : {'text': u'These LinkNYC kiosks popping up everywhere are pure Dopeness.    Serves so many meaningful purposes...'}
#
# 5 : {'text': u'RT @TheStoopBK: New Free Wi-Fi/Phone Charging Kiosks Installed Along 5th Avenue @LinkNYC\nhttps://t.co/Rz3qzRjsww https://t.co/ggKkKkva1P'}
#
# ...

# %%
# 전체 문서를 파일 저장
import os

wfile = open(os.getcwd()+"/twitter.txt", mode='w')   # 쓰기 모드
data = {}   # 전체 문서 추가
i = 0       # 문서 번호

for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    wfile.write(data['text']+'\n')  # 파일 출력
    i += 1

wfile.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-8-5c88a83893bc> in <module>()
#       8 for tweet in search:
#       9     data['text'] = tweet.text   # text키에 text문서 저장
# ---> 10     wfile.write(data['text']+'\n')  # 파일 출력
#      11     i += 1
#      12
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 47-50: ordinal not in range(128)

# %% [markdown]
# # Streaming

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print "&quot;Error on_data: %s&quot; % str(e)"
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#python'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ab3b557445de> in <module>()
#      18
#      19 twitter_stream = Stream(auth, MyListener())
# ---> 20 twitter_stream.filter(track=['#python'])
#
# c:\python27\lib\site-packages\tweepy\streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# c:\python27\lib\site-packages\tweepy\streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# c:\python27\lib\site-packages\tweepy\streaming.pyc in _run(self)
# ...

# %%
while(page<=3):
    tweets=api.GetSearch("#Egypt since:2014-02-01 until:2014-02-05t",per_page=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-50b6244613af> in <module>()
# ----> 1 while(page<=3):
#       2     tweets=api.GetSearch("#Egypt since:2014-02-01 until:2014-02-05t",per_page=10)
#
# NameError: name 'page' is not defined
