# %% [markdown]
# ### What is the difference between residence and workplace geography?
#
# **Residence geography** refers to the geographic location at which the respondent resides during the reference week.
#
# **Workplace geography** refers to the geographic location of the respondent’s workplace, also referred to as “place of work”. Questions about place of work are asked of respondents who indicated that they worked at some time during the reference week. The place of work refers to the geographic location at which workers carried out their occupational activities during the reference week.
#
# In the ACS, there are tables for residence geography and those for workplace geography. Unless the table indicates otherwise, it refers to residence-based geography. Other tables that indicate they are for workplace geography refer to the worker population who works in an area. For example, in the ACS Table B08007: SEX OF WORKERS BY PLACE OF WORK contains the number of workers living in an area crossed by sex, while ACS Table B08406: SEX OF WORKERS BY MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY contains the number of workers who work in an area crossed by sex and means of transportation to work.
#
# https://www.census.gov/hhes/commuting/about/faq.html

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Preprocessing1.

# %%
MEANS_OF_TRANSPORTATION_BY_POVERTY_STATUS = pd.read_excel('~/dss4/LinkNYC/transportation_data/MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS.xls')
MEANS_OF_TRANSPORTATION_BY_POVERTY_STATUS
# Out:
#    C08122: MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS - Universe: Workers 16 years and over for whom poverty status is determined  \
# 0     2015 American Community Survey 1-Year Estimates
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Total:
# 8              Below 100 percent of the poverty level
# 9             100 to 149 percent of the poverty level
# 10       At or above 150 percent of the poverty level
# 11                  Car, truck, or van - drove alone:
# 12             Below 100 percent of the poverty level
# 13            100 to 149 percent of the poverty level
# ...

# %% [markdown]
# ### Preprocessing2. PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL

# %%
PLACE_OF_WORK = pd.read_excel('~/dss4/LinkNYC/transportation_data/PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL.xls')
PLACE_OF_WORK
# Out:
#    C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area  \
# 0     2015 American Community Survey 1-Year Estimates
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Total:
# 8     Worked in Metropolitan Statistical Area of r...
# 9                          Worked in a principal city
# 10                  Worked outside any principal city
# 11    Worked in a different Metropolitan Statistic...
# 12                         Worked in a principal city
# 13                  Worked outside any principal city
# ...

# %%
PLACE_OF_WORK = PLACE_OF_WORK.rename(columns={'Unnamed: 3': 'Estimate', 'Unnamed: 6': 'Margin of Error'})
PLACE_OF_WORK
# Out:
#    C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area  \
# 0     2015 American Community Survey 1-Year Estimates
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Total:
# 8     Worked in Metropolitan Statistical Area of r...
# 9                          Worked in a principal city
# 10                  Worked outside any principal city
# 11    Worked in a different Metropolitan Statistic...
# 12                         Worked in a principal city
# 13                  Worked outside any principal city
# ...

# %%
PLACE_OF_WORK.drop(PLACE_OF_WORK.columns[[1, 2, 4, 5]], axis=1, inplace=True)
PLACE_OF_WORK
# Out:
#    C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area  \
# 0     2015 American Community Survey 1-Year Estimates
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Total:
# 8     Worked in Metropolitan Statistical Area of r...
# 9                          Worked in a principal city
# 10                  Worked outside any principal city
# 11    Worked in a different Metropolitan Statistic...
# 12                         Worked in a principal city
# 13                  Worked outside any principal city
# ...

# %%
PLACE_OF_WORK = PLACE_OF_WORK.drop(PLACE_OF_WORK.index[range(7)])
PLACE_OF_WORK
# Out:
#    C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area  \
# 7                                              Total:
# 8     Worked in Metropolitan Statistical Area of r...
# 9                          Worked in a principal city
# 10                  Worked outside any principal city
# 11    Worked in a different Metropolitan Statistic...
# 12                         Worked in a principal city
# 13                  Worked outside any principal city
# 14          Worked in a Micropolitan Statistical Area
# 15    Worked outside any Metropolitan or Micropoli...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# ...

# %%
PLACE_OF_WORK = PLACE_OF_WORK.drop(PLACE_OF_WORK.index[range(9, 21)])
PLACE_OF_WORK
# Out:
#    C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area  \
# 7                                              Total:
# 8     Worked in Metropolitan Statistical Area of r...
# 9                          Worked in a principal city
# 10                  Worked outside any principal city
# 11    Worked in a different Metropolitan Statistic...
# 12                         Worked in a principal city
# 13                  Worked outside any principal city
# 14          Worked in a Micropolitan Statistical Area
# 15    Worked outside any Metropolitan or Micropoli...
#
#      Estimate Margin of Error
# 7   3,992,612       +/-21,149
# 8   3,953,634       +/-21,160
# 9   3,731,459       +/-21,396
# 10    222,175        +/-9,593
# 11     33,965        +/-3,194
# 12     18,238        +/-2,028
# 13     15,727        +/-2,340
# 14      1,639          +/-629
# ...

# %%
PLACE_OF_WORK = PLACE_OF_WORK.rename(columns={'C08016: PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL - Universe: Workers 16 years and over living in a metropolitan statistical area': 'Type'})
PLACE_OF_WORK
# Out:
#                                                  Type   Estimate  \
# 7                                              Total:  3,992,612
# 8     Worked in Metropolitan Statistical Area of r...  3,953,634
# 9                          Worked in a principal city  3,731,459
# 10                  Worked outside any principal city    222,175
# 11    Worked in a different Metropolitan Statistic...     33,965
# 12                         Worked in a principal city     18,238
# 13                  Worked outside any principal city     15,727
# 14          Worked in a Micropolitan Statistical Area      1,639
# 15    Worked outside any Metropolitan or Micropoli...      3,374
#
#    Margin of Error
# 7        +/-21,149
# 8        +/-21,160
# 9        +/-21,396
# 10        +/-9,593
# 11        +/-3,194
# 12        +/-2,028
# 13        +/-2,340
# 14          +/-629
# 15        +/-1,107

# %%
PLACE_OF_WORK = PLACE_OF_WORK.set_index("Type")
PLACE_OF_WORK
# Out:
#                                                      Estimate Margin of Error
# Type
# Total:                                              3,992,612       +/-21,149
#   Worked in Metropolitan Statistical Area of re...  3,953,634       +/-21,160
#     Worked in a principal city                      3,731,459       +/-21,396
#     Worked outside any principal city                 222,175        +/-9,593
#   Worked in a different Metropolitan Statistica...     33,965        +/-3,194
#     Worked in a principal city                         18,238        +/-2,028
#     Worked outside any principal city                  15,727        +/-2,340
#   Worked in a Micropolitan Statistical Area             1,639          +/-629
#   Worked outside any Metropolitan or Micropolit...      3,374        +/-1,107

# %%
PLACE_OF_WORK.to_csv('~/dss4/LinkNYC/transportation_data/(Preprocessed)PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL.csv')

# %%
PLACE_OF_WORK = pd.read_csv('~/dss4/LinkNYC/transportation_data/(Preprocessed)PLACE OF WORK FOR WORKERS 16 YEARS AND OVER--METROPOLITAN STATISTICAL AREA LEVEL.csv')
PLACE_OF_WORK
# Out:
#                                                 Type   Estimate  \
# 0                                             Total:  3,992,612
# 1    Worked in Metropolitan Statistical Area of r...  3,953,634
# 2                         Worked in a principal city  3,731,459
# 3                  Worked outside any principal city    222,175
# 4    Worked in a different Metropolitan Statistic...     33,965
# 5                         Worked in a principal city     18,238
# 6                  Worked outside any principal city     15,727
# 7          Worked in a Micropolitan Statistical Area      1,639
# 8    Worked outside any Metropolitan or Micropoli...      3,374
#
#   Margin of Error
# 0       +/-21,149
# 1       +/-21,160
# 2       +/-21,396
# 3        +/-9,593
# 4        +/-3,194
# 5        +/-2,028
# 6        +/-2,340
# 7          +/-629
# 8        +/-1,107
